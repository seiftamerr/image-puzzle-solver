# %%
import cv2
import numpy as np
import os
from itertools import permutations

EDGE_THICKNESS = 3
ERROR_LIMIT = 300
SAVE_DIR = "./results/2x2_out"


# ---------------- IMAGE SLICING ----------------
def slice_image_quadrants(img):
    h, w = img.shape[:2]
    h2, w2 = h // 2, w // 2
    return [
        img[:h2, :w2],
        img[:h2, w2:],
        img[h2:, :w2],
        img[h2:, w2:]
    ]


# ---------------- EDGE HANDLING ----------------
def extract_edge_strip(img, side):
    t = EDGE_THICKNESS
    return {
        'top': img[:t],
        'bottom': img[-t:],
        'left': img[:, :t],
        'right': img[:, -t:]
    }[side]


def compute_edge_descriptor(edge):
    edge = cv2.GaussianBlur(edge, (3,3), 0)

    lab  = cv2.cvtColor(edge, cv2.COLOR_BGR2LAB).astype(np.float32)
    gray = cv2.cvtColor(edge, cv2.COLOR_BGR2GRAY).astype(np.float32)

    gx = cv2.Sobel(gray, cv2.CV_32F, 1, 0)
    gy = cv2.Sobel(gray, cv2.CV_32F, 0, 1)

    grad = np.sqrt(gx**2 + gy**2)[...,None]
    lap  = cv2.Laplacian(gray, cv2.CV_32F)[...,None]

    return np.concatenate([lab, grad, lap], axis=2)


def standardize_features(f):
    f = f.copy()
    for c in range(f.shape[2]):
        mu, sigma = f[...,c].mean(), f[...,c].std()
        f[...,c] = (f[...,c] - mu) / (sigma if sigma > 1e-6 else 1)
    return f


def compare_edge_similarity(a, b, sa, sb):
    a = standardize_features(a)
    b = standardize_features(b)

    if sa in ('left','right'):
        a = np.transpose(a, (1,0,2))
    if sb in ('left','right'):
        b = np.transpose(b, (1,0,2))

    if a.shape != b.shape:
        b = cv2.resize(b, (a.shape[1], a.shape[0]))

    diff = np.abs(a - b)

    return (
        0.5 * diff[...,0:3].mean() +
        0.3 * diff[...,3].mean() +
        0.2 * diff[...,4].mean()
    )


# ---------------- OPTIMIZATION ----------------
def generate_edge_costs(pieces):
    sides = ['top','bottom','left','right']
    opposite = {'top':'bottom','bottom':'top','left':'right','right':'left'}
    n = len(pieces)

    descriptors = {
        (i,s): compute_edge_descriptor(extract_edge_strip(p,s))
        for i,p in enumerate(pieces)
        for s in sides
    }

    costs = {s: np.full((n,n), np.inf) for s in sides}

    for i in range(n):
        for j in range(n):
            if i == j:
                continue
            for s in sides:
                costs[s][i,j] = compare_edge_similarity(
                    descriptors[(i,s)],
                    descriptors[(j,opposite[s])],
                    s, opposite[s]
                )
    return costs


def optimize_2x2_layout(pieces):
    cost = generate_edge_costs(pieces)
    best, runner_up = None, 1e18
    best_score = 1e18

    for p in permutations(range(4)):
        score = (
            cost['right'][p[0], p[1]] +
            cost['bottom'][p[0], p[2]] +
            cost['right'][p[2], p[3]] +
            cost['bottom'][p[1], p[3]]
        )
        if score < best_score:
            runner_up = best_score
            best_score = score
            best = p
        elif score < runner_up:
            runner_up = score

    return list(best), runner_up - best_score


# ---------------- RECONSTRUCTION ----------------
def reconstruct_image(pieces, order):
    h, w = pieces[0].shape[:2]
    canvas = np.zeros((2*h,2*w,3), np.uint8)

    canvas[:h,:w]     = pieces[order[0]]
    canvas[:h,w:]     = pieces[order[1]]
    canvas[h:,:w]     = pieces[order[2]]
    canvas[h:,w:]     = pieces[order[3]]

    return canvas


def mean_squared_error(a, b):
    if a.shape != b.shape:
        b = cv2.resize(b, (a.shape[1], a.shape[0]))
    return np.mean((a.astype(np.float32) - b.astype(np.float32))**2)


# ---------------- PIPELINE ----------------
def run_solver_and_evaluate(puzzle_dir, gt_dir):
    os.makedirs(SAVE_DIR, exist_ok=True)

    files = sorted(
        [f for f in os.listdir(puzzle_dir) if f.lower().endswith(('.png','.jpg'))],
        key=lambda x: int(''.join(c for c in x if c.isdigit()) or 0)
    )

    correct = total = 0

    print("\n[INFO] Edge-driven 2x2 Puzzle Reconstruction")
    print("-"*60)

    for idx, fname in enumerate(files, 1):
        img = cv2.imread(os.path.join(puzzle_dir, fname))
        if img is None:
            continue

        pieces = slice_image_quadrants(img)
        order, confidence = optimize_2x2_layout(pieces)
        result = reconstruct_image(pieces, order)

        pid = os.path.splitext(fname)[0]
        cv2.imwrite(os.path.join(SAVE_DIR, pid+".png"), result)

        gt = cv2.imread(os.path.join(gt_dir, pid+".png"))
        if gt is None:
            continue

        err = mean_squared_error(result, gt)
        passed = err < ERROR_LIMIT

        correct += passed
        total += 1

        print(f"{idx:3d} | {pid:<6} | error={err:7.1f} | "
              f"{'OK' if passed else 'FAIL'} | confidence={confidence:.2f}")

    print("-"*60)
    print(f"Accuracy: {correct}/{total} = {100*correct/total:.2f}%")
    print(f"Saved results in: {SAVE_DIR}\n")


if __name__ == "__main__":
    run_solver_and_evaluate(
        r"C:\Term 5\image_project\OneDrive_2025-11-26\Jigsaw Puzzle Dataset\Gravity Falls\puzzle_2x2",
        r"C:\Term 5\image_project\OneDrive_2025-11-26\Jigsaw Puzzle Dataset\Gravity Falls\correct"
    )
# Out:
# [INFO] Edge-driven 2x2 Puzzle Reconstruction
# ------------------------------------------------------------
#   1 | 0      | error=   64.9 | OK | confidence=0.47
#   2 | 1      | error=   15.7 | OK | confidence=0.59
#   3 | 2      | error=   32.4 | OK | confidence=0.57
#   4 | 3      | error= 9669.3 | FAIL | confidence=0.11
#   5 | 4      | error= 9586.5 | FAIL | confidence=0.76
#   6 | 5      | error= 9093.2 | FAIL | confidence=0.92
#   7 | 6      | error= 9173.1 | FAIL | confidence=0.51
#   8 | 7      | error=   11.5 | OK | confidence=0.63
#   9 | 8      | error=   26.2 | OK | confidence=0.82
#  10 | 9      | error=   29.6 | OK | confidence=0.67
#  11 | 10     | error=   24.2 | OK | confidence=0.13
#  12 | 11     | error=   29.6 | OK | confidence=0.71
#  13 | 12     | error=   24.2 | OK | confidence=0.46
#  14 | 13     | error=   38.2 | OK | confidence=0.47
#  15 | 14     | error=   56.9 | OK | confidence=0.55
#  16 | 15     | error=   64.1 | OK | confidence=0.68
#  17 | 16     | error=   17.4 | OK | confidence=1.01
#  18 | 17     | error=   25.7 | OK | confidence=0.43
#  19 | 18     | error=   19.6 | OK | confidence=0.41
#  20 | 19     | error=   28.7 | OK | confidence=0.67
#  21 | 20     | error=   45.5 | OK | confidence=0.74
#  22 | 21     | error=   11.2 | OK | confidence=0.55
#  23 | 22     | error=   19.2 | OK | confidence=0.35
#  24 | 23     | error=   27.5 | OK | confidence=0.95
#  25 | 24     | error=   10.4 | OK | confidence=0.72
#  26 | 25     | error=    8.9 | OK | confidence=0.84
#  27 | 26     | error=    5.0 | OK | confidence=0.38
#  28 | 27     | error=   13.4 | OK | confidence=0.62
#  29 | 28     | error=   16.3 | OK | confidence=0.61
#  30 | 29     | error=   26.2 | OK | confidence=0.49
#  31 | 30     | error=   18.4 | OK | confidence=0.78
#  32 | 31     | error= 5614.7 | FAIL | confidence=0.18
#  33 | 32     | error= 3213.8 | FAIL | confidence=0.93
#  34 | 33     | error=10645.5 | FAIL | confidence=0.56
#  35 | 34     | error=10717.2 | FAIL | confidence=0.73
#  36 | 35     | error=   32.5 | OK | confidence=0.70
#  37 | 36     | error=   15.6 | OK | confidence=0.26
#  38 | 37     | error=   64.5 | OK | confidence=0.51
#  39 | 38     | error=   33.9 | OK | confidence=0.82
#  40 | 39     | error=   16.8 | OK | confidence=0.97
#  41 | 40     | error=  103.7 | OK | confidence=0.37
#  42 | 41     | error=10106.7 | FAIL | confidence=1.07
#  43 | 42     | error= 7971.3 | FAIL | confidence=0.18
#  44 | 43     | error= 6239.0 | FAIL | confidence=0.20
#  45 | 44     | error= 7320.2 | FAIL | confidence=0.67
#  46 | 45     | error= 7302.2 | FAIL | confidence=0.64
#  47 | 46     | error=   21.0 | OK | confidence=0.36
#  48 | 47     | error=   14.0 | OK | confidence=0.66
#  49 | 48     | error= 9890.8 | FAIL | confidence=1.00
#  50 | 49     | error=   19.5 | OK | confidence=0.05
#  51 | 50     | error=   28.8 | OK | confidence=1.18
#  52 | 51     | error= 9929.5 | FAIL | confidence=0.65
#  53 | 52     | error=   10.2 | OK | confidence=1.03
#  54 | 53     | error= 4441.5 | FAIL | confidence=0.84
#  55 | 54     | error= 4442.7 | FAIL | confidence=0.92
#  56 | 55     | error=    6.9 | OK | confidence=0.52
#  57 | 56     | error=   10.1 | OK | confidence=0.49
#  58 | 57     | error=   11.2 | OK | confidence=0.45
#  59 | 58     | error=   17.0 | OK | confidence=0.57
#  60 | 59     | error=   21.0 | OK | confidence=1.02
#  61 | 60     | error=   22.7 | OK | confidence=0.91
#  62 | 61     | error=   23.7 | OK | confidence=0.78
#  63 | 62     | error=    5.8 | OK | confidence=0.88
#  64 | 63     | error=   11.9 | OK | confidence=0.41
#  65 | 64     | error=   17.6 | OK | confidence=1.20
#  66 | 65     | error=   17.6 | OK | confidence=1.12
#  67 | 66     | error=    6.9 | OK | confidence=1.35
#  68 | 67     | error=   25.8 | OK | confidence=0.66
#  69 | 68     | error=   11.7 | OK | confidence=0.99
#  70 | 69     | error=   10.3 | OK | confidence=0.98
#  71 | 70     | error=    8.7 | OK | confidence=1.11
#  72 | 71     | error=   11.4 | OK | confidence=1.08
#  73 | 72     | error=   17.9 | OK | confidence=0.15
#  74 | 73     | error= 7473.8 | FAIL | confidence=0.95
#  75 | 74     | error= 7478.4 | FAIL | confidence=0.63
#  76 | 75     | error=    3.1 | OK | confidence=0.84
#  77 | 76     | error= 8337.7 | FAIL | confidence=0.44
#  78 | 77     | error= 6648.9 | FAIL | confidence=0.77
#  79 | 78     | error= 7610.8 | FAIL | confidence=0.58
#  80 | 79     | error=    6.9 | OK | confidence=0.55
#  81 | 80     | error=10726.2 | FAIL | confidence=0.65
#  82 | 81     | error=   10.6 | OK | confidence=0.94
#  83 | 82     | error=    4.5 | OK | confidence=1.11
#  84 | 83     | error=10684.6 | FAIL | confidence=0.32
#  85 | 84     | error= 8481.4 | FAIL | confidence=1.20
#  86 | 85     | error= 8447.5 | FAIL | confidence=0.86
#  87 | 86     | error=    9.0 | OK | confidence=0.70
#  88 | 87     | error=   20.8 | OK | confidence=1.02
#  89 | 88     | error=   10.5 | OK | confidence=0.90
#  90 | 89     | error=    4.9 | OK | confidence=1.18
#  91 | 90     | error=    9.0 | OK | confidence=0.63
#  92 | 91     | error=   14.2 | OK | confidence=0.35
#  93 | 92     | error=   16.6 | OK | confidence=0.25
#  94 | 93     | error=13530.2 | FAIL | confidence=0.32
#  95 | 94     | error=13993.0 | FAIL | confidence=0.59
#  96 | 95     | error=    7.0 | OK | confidence=0.85
#  97 | 96     | error=   50.1 | OK | confidence=0.73
#  98 | 97     | error= 9427.2 | FAIL | confidence=0.96
#  99 | 98     | error= 9341.1 | FAIL | confidence=0.10
# 100 | 99     | error=   16.2 | OK | confidence=0.43
# 101 | 100    | error=   31.5 | OK | confidence=0.77
# 102 | 101    | error=   23.7 | OK | confidence=0.51
# 103 | 102    | error=   37.4 | OK | confidence=0.71
# 104 | 103    | error=   57.3 | OK | confidence=0.59
# 105 | 104    | error=   48.4 | OK | confidence=0.45
# 106 | 105    | error= 6338.1 | FAIL | confidence=0.02
# 107 | 106    | error=   44.4 | OK | confidence=0.72
# 108 | 107    | error=   29.4 | OK | confidence=0.59
# 109 | 108    | error=    8.9 | OK | confidence=0.72
# 110 | 109    | error=   41.8 | OK | confidence=0.85
# ------------------------------------------------------------
# Accuracy: 79/110 = 71.82%
# Saved results in: ./results/2x2_out
